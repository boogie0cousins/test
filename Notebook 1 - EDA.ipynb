# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"><li><span><a href="#Preprocessing-Step" data-toc-modified-id="Preprocessing-Step-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Preprocessing Step</a></span><ul class="toc-item"><li><span><a href="#Read-data" data-toc-modified-id="Read-data-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Read data</a></span></li><li><span><a href="#Plot-the-data" data-toc-modified-id="Plot-the-data-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Plot the data</a></span></li><li><span><a href="#Identify-Outliers" data-toc-modified-id="Identify-Outliers-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Identify Outliers</a></span><ul class="toc-item"><li><span><a href="#Outliers-using-Z-score" data-toc-modified-id="Outliers-using-Z-score-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Outliers using Z-score</a></span></li><li><span><a href="#Outliers-usng-Modified-Z-score" data-toc-modified-id="Outliers-usng-Modified-Z-score-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Outliers usng Modified Z-score</a></span></li><li><span><a href="#Outliers-using-InterQuartile-Range" data-toc-modified-id="Outliers-using-InterQuartile-Range-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>Outliers using InterQuartile Range</a></span></li></ul></li><li><span><a href="#Fix-the-outliers-using-IQR-method" data-toc-modified-id="Fix-the-outliers-using-IQR-method-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Fix the outliers using IQR method</a></span></li></ul></li><li><span><a href="#Correlation-between-Signal-and-ClosePrice" data-toc-modified-id="Correlation-between-Signal-and-ClosePrice-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Correlation between Signal and ClosePrice</a></span></li><li><span><a href="#Relationship-between-Signal-and-ClosePrice" data-toc-modified-id="Relationship-between-Signal-and-ClosePrice-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Relationship between Signal and ClosePrice</a></span></li><li><span><a href="#Modeling" data-toc-modified-id="Modeling-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Modeling</a></span></li><li><span><a href="#Quality-Check-of-Model" data-toc-modified-id="Quality-Check-of-Model-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Quality Check of Model</a></span><ul class="toc-item"><li><span><a href="#Linear-relationship" data-toc-modified-id="Linear-relationship-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Linear relationship</a></span></li><li><span><a href="#Mean-of-residuals-should-be-0" data-toc-modified-id="Mean-of-residuals-should-be-0-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Mean of residuals should be 0</a></span></li><li><span><a href="#Residuals-are-homoscedastic" data-toc-modified-id="Residuals-are-homoscedastic-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Residuals are homoscedastic</a></span><ul class="toc-item"><li><span><a href="#Residual-vs-Fitted-values-plot" data-toc-modified-id="Residual-vs-Fitted-values-plot-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Residual vs Fitted values plot</a></span></li><li><span><a href="#Breusch-Pagan-Test" data-toc-modified-id="Breusch-Pagan-Test-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>Breusch-Pagan Test</a></span></li></ul></li><li><span><a href="#Residuals-are-uncorrelated" data-toc-modified-id="Residuals-are-uncorrelated-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Residuals are uncorrelated</a></span><ul class="toc-item"><li><span><a href="#Plotting-Autocorrelation-Function" data-toc-modified-id="Plotting-Autocorrelation-Function-5.4.1"><span class="toc-item-num">5.4.1&nbsp;&nbsp;</span>Plotting Autocorrelation Function</a></span></li><li><span><a href="#Durbin-Watson-Test" data-toc-modified-id="Durbin-Watson-Test-5.4.2"><span class="toc-item-num">5.4.2&nbsp;&nbsp;</span>Durbin-Watson Test</a></span></li><li><span><a href="#Fix" data-toc-modified-id="Fix-5.4.3"><span class="toc-item-num">5.4.3&nbsp;&nbsp;</span>Fix</a></span></li></ul></li><li><span><a href="#Independent-variable-and-residuals-are-uncorrelated" data-toc-modified-id="Independent-variable-and-residuals-are-uncorrelated-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Independent variable and residuals are uncorrelated</a></span></li><li><span><a href="#Normality-test-of-residuals" data-toc-modified-id="Normality-test-of-residuals-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Normality test of residuals</a></span><ul class="toc-item"><li><span><a href="#Jarque-Barra-test" data-toc-modified-id="Jarque-Barra-test-5.6.1"><span class="toc-item-num">5.6.1&nbsp;&nbsp;</span>Jarque-Barra test</a></span></li><li><span><a href="#Fixes" data-toc-modified-id="Fixes-5.6.2"><span class="toc-item-num">5.6.2&nbsp;&nbsp;</span>Fixes</a></span></li></ul></li></ul></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Conclusion</a></span></li><li><span><a href="#Future-Work:" data-toc-modified-id="Future-Work:-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Future Work:</a></span><ul class="toc-item"><li><span><a href="#Feature-Engineering" data-toc-modified-id="Feature-Engineering-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Feature Engineering</a></span><ul class="toc-item"><li><span><a href="#DateTime-based-features" data-toc-modified-id="DateTime-based-features-7.1.1"><span class="toc-item-num">7.1.1&nbsp;&nbsp;</span>DateTime-based features</a></span></li><li><span><a href="#Technical-Indicators" data-toc-modified-id="Technical-Indicators-7.1.2"><span class="toc-item-num">7.1.2&nbsp;&nbsp;</span>Technical Indicators</a></span></li><li><span><a href="#Lagged-Features" data-toc-modified-id="Lagged-Features-7.1.3"><span class="toc-item-num">7.1.3&nbsp;&nbsp;</span>Lagged Features</a></span></li></ul></li><li><span><a href="#Advanced-Machine-Learning-Models" data-toc-modified-id="Advanced-Machine-Learning-Models-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Advanced Machine Learning Models</a></span></li></ul></li></ul></div>

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
import matplotlib.gridspec as gridspec
import seaborn as sns
import datetime
import os
import sys
import scipy.stats as stats
import statsmodels.api as sm
import statsmodels.stats.api as sms
import statsmodels.tsa.api as smt

from statsmodels.graphics.regressionplots import abline_plot
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
from IPython.display import display

# %% [markdown]
# # Preprocessing Step

# %% [markdown]
# ## Read data

# %%
def glance(df, n=5):
    """
    Glance the data via shape/head/tail
    """
    print("Data Shape: [{0}, {1}]".format(*df.shape))
    display(df.head(n))
    display(df.tail(n))

# %%
data = pd.read_excel('ResearchDatasetV2.0.xlsx', index_col=0, parse_dates=['Date'])
glance(data)
# Out:
# Data Shape: [667, 2]
#               Signal  ClosePrice
# Date
# 2012-01-03  3.107767     127.495
# 2012-01-04  3.107282     127.700
# 2012-01-05  3.099757     128.040
# 2012-01-06  3.134223     127.710
# 2012-01-09  3.135922     128.020
#               Signal  ClosePrice
# Date
# 2014-08-25  4.869175      200.20
# 2014-08-26  4.866505      200.33
# 2014-08-27  4.859468      200.25
# 2014-08-28  4.881311      200.14
# 2014-08-29  4.868689      200.71

# %% [markdown]
# One of the first steps in data analysis is to check missing entries.

# %%
data.isnull().any().to_frame('Any Null/NaN Entry?')
# Out:
#             Any Null/NaN Entry?
# Signal                    False
# ClosePrice                False

# %% [markdown]
# > <font color='red'>**Comment:**
# > - No missing data in either of the columns</font>

# %% [markdown]
# Next step is to check for any weekend data entry. This is because trading happens on weekdays. So any weekend data entries must be removed.

# %%
def check_weekend_data(df):
    """
    Check if data occurs on weekend
    """
    # Day of week with values of 5, 6 represents Saturday and Sunday in Pandas DateTimeIndex
    df['IsWeekend'] = np.where(df.index.dayofweek.isin([5, 6]), True, False)
    return df[df['IsWeekend'] == True]

# %%
check_weekend_data(data)
# Out:
#               Signal  ClosePrice  IsWeekend
# Date
# 2014-02-08  4.466505      179.68       True
# 2014-02-09  4.466505      179.68       True

# %% [markdown]
# > <font color='red'>**Comment:**
# > - Weekend data exists in our dataset for couple of days. Let's remove them since there is no trading usually on weekends.

# %% [markdown]
# Remove these weekend entries from our data.

# %%
def drop_weekend_data(df):
    """
    Drop weekend data
    """
    _df = df.copy()

    # Keep weekdays
    _df = _df[_df['IsWeekend'] == False]
    return _df.drop(['IsWeekend'], axis=1)

# %%
data = drop_weekend_data(data)
glance(data)
# Out:
# Data Shape: [665, 2]
#               Signal  ClosePrice
# Date
# 2012-01-03  3.107767     127.495
# 2012-01-04  3.107282     127.700
# 2012-01-05  3.099757     128.040
# 2012-01-06  3.134223     127.710
# 2012-01-09  3.135922     128.020
#               Signal  ClosePrice
# Date
# 2014-08-25  4.869175      200.20
# 2014-08-26  4.866505      200.33
# 2014-08-27  4.859468      200.25
# 2014-08-28  4.881311      200.14
# 2014-08-29  4.868689      200.71

# %% [markdown]
# > <font color='red'>**Comment:**
# > - Only weekday data now exists </font>

# %% [markdown]
# Let's further see the data types and distribution of the data.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 665 entries, 2012-01-03 to 2014-08-29
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Signal      665 non-null    float64
#  1   ClosePrice  665 non-null    float64
# dtypes: float64(2)
# memory usage: 15.6 KB

# %% [markdown]
# > <font color='red'>**Comment:**
# > - Both the given time-series are float values and there are no missing entries in either of them.

# %%
data.describe()
# Out:
#            Signal  ClosePrice
# count  665.000000  665.000000
# mean     5.168908  163.119713
# std     23.427981   39.258904
# min     -3.802670  127.495000
# 25%      3.417718  140.850000
# 50%      3.886893  159.680000
# 75%      4.405583  181.510000
# max    432.961165  710.310000

# %% [markdown]
# > <font color='red'>**Comment:**
# > - Distribution of the `Signal` and `ClosePrice` clearly shows the presence of outliers in each series based on the maximum value of the data distribution table. Let's plot the time-series and confirm the presence of outliers.

# %% [markdown]
# ## Plot the data

# %% [markdown]
# Different types of plots that helps to identify outliers:
#
# - Box plot
# - Scatter plot
# - Distribution plot (histogram)
# - Moving average of the time-series etc.
#
# Below are some utility functions to assist in plotting different charts.

# %%
def get_color(column):
    """
    Get color for plot depending upon column name
    """
    return 'lightcoral' if column == 'Signal' else 'dodgerblue'

def get_colors(column):
    """
    Get pair of colors depending upon column name
    """
    return ('lightcoral', 'maroon') if column == 'Signal' else ('dodgerblue', 'blue')

    
def scatter_plot(x, y, ax):
    """
    Scatter plot between signal and close price
    """
    ax.scatter(x=x, y=y, marker='o', color='sandybrown', edgecolor='black')
    ax.set(title='Scatter Plot of Signal vs ClosePrice',
           xlabel='Signal',
           ylabel='ClosePrice')

def add_legend(ax):
    """
    Add legend to given axes
    """
    leg = ax.legend(loc='best', frameon=True, framealpha=1)
    leg.get_frame().set_edgecolor('black')
    
    
def cross_correlation_plot(df, x, y, ax):
    """
    Cross-correlation plot
    """
    xseries = df[x]
    yseries = df[y]
    
    # Calculates lags and correlation values
    lags, c, line, b = ax.xcorr(xseries, yseries, usevlines=True, maxlags=50, normed=True, lw=2)
    
    # Identify lag with max correlation value
    # and highlight that point
    max_val_idx = c.argmax()
    ax.axvline(x=lags[max_val_idx], color='lime', linestyle='-', 
               label=f'Max correlation = {c[max_val_idx].round(2)} at Lag = {lags[max_val_idx]} of {x}')
    
    ax.set(title='Cross-correlation between Signal and ClosePrice',
           xlabel='Lags',
           ylabel='Pearson correlation')
    
    add_legend(ax)
    
    
def rolling_correlation_plot(df, ax, sma_days=[10, 21]):
    """
    Rolling correlation plot
    """
    for days in sma_days:
        rolling_corr_df = df['Signal'].rolling(window=days, center=True).corr(df['ClosePrice'])
        rolling_corr_df.plot(ax=ax, label=f'{days}-Day Rolling Pearson Correlation')
        
    ax.set(title='Rolling Pearson Correlation between Signal and ClosePrice [{0}]'.format(", ".join(['{0} days'.format(str(x)) for x in sma_days])),
           xlabel='Date',
           ylabel='Correlation')
    add_legend(ax)
    

def line_plot(df, column, ax, sma_days=10):
    """
    Line plot for given time series
    """
    color1, color2 = get_colors(column)
    series = df[column]
    series.plot(ax=ax, color=color1, label=f'{column}')
    series.rolling(sma_days).mean().plot(ax=ax, color=color2, alpha=0.7, label=f'{column} {sma_days}-day Moving Average')
    ax.set(title=f'{column} time series',
           xlabel='Date',
           ylabel=f'{column}')
    add_legend(ax)
    

def distribution_plot(df, column, ax):
    """
    Distribution plot
    """
    color = get_color(column)
    series = df[column]
    sns.distplot(series, color=color, ax=ax, 
                 hist_kws=dict(edgecolor="k", linewidth=2), 
                 bins=30, hist=True, label=f'{column}')
    
    ax.set_title(f'Distribution of {column}')
    add_legend(ax)
    

def box_plot(df, column, ax):
    """
    Box plot
    """
    series = df[column]
    color = get_color(column)
    sns.boxplot(series, color=color, ax=ax)
    ax.set(title=f'Box plot for {column}')

# %%
def plots_for_outliers(df):
    """
    Useful plots for checking outliers time-series data
    """
    signal = df['Signal']
    close_price = df['ClosePrice']
    
    grid = gridspec.GridSpec(nrows=5, ncols=2)

    fig = plt.figure(figsize=(15, 15))
    fig.clf()

    # Add axes which can span multiple grid boxes
    ax1 = fig.add_subplot(grid[0, :])
    ax2 = fig.add_subplot(grid[1, 0])
    ax3 = fig.add_subplot(grid[1, 1])
    ax4 = fig.add_subplot(grid[2, 0])
    ax5 = fig.add_subplot(grid[2, 1])
    ax6 = fig.add_subplot(grid[3, 0])
    ax7 = fig.add_subplot(grid[3, 1])
    
    # Scatter plot
    scatter_plot(x=signal, y=close_price, ax=ax1)
    
    # Time series plots
    line_plot(df, column='Signal', ax=ax2, sma_days=10)
    line_plot(df, column='ClosePrice', ax=ax3, sma_days=10)
    
    # Distribution plots
    distribution_plot(df, column='Signal', ax=ax4)
    distribution_plot(df, column='ClosePrice', ax=ax5)
        
    # Box plots
    box_plot(df, column='Signal', ax=ax6)
    box_plot(df, column='ClosePrice', ax=ax7)
    
    fig.tight_layout()
    plt.show()

# %%
plots_for_outliers(data)

# %% [markdown]
# > <font color='red'>**Comment:**
# > - Scatter plot clearly shows the presence of outliers (both for `Signal` and `ClosePrice`)
# > - Individual time-series plots also shows a big spike due to these outliers.
# > - Box plot also confirms the presence of outliers (highlighted as dots)
# > - Next step would be to identify and fix these outlier values (either filling them with appropriate value or removing them altogether from the data)

# %% [markdown]
# ## Identify Outliers

# %% [markdown]
# There are multiple ways to identify outliers given a dataset. Few of the these include:
#
# 1. Z-score: Z-scores are the number of standard deviations above and below the mean that each value falls
#
# 2. Modified Z-score: More robust than Z-score since it relies on median (and not mean) to detect outliers, so less influenced by outliers compared to traditional Z-score
#
# 3. Interquartile range: Measure of statistical dispersion, equal to the difference between 75th and 25th percentiles or between upper and lower quartiles

# %%
def get_numpy_array(series):
    """
    Convert a series to numpy.array
    """
    if not isinstance(series, np.ndarray):
        series = np.array(series)
    return series

def get_zscore(series):
    """
    Get Z-score using scipy.stats method
    """
    return np.abs(stats.zscore(series))


def get_outliers_using_zscore(series, threshold=3):
    """
    Identify the outliers using Z-score method
    """
    series = get_numpy_array(series)    
    z_score = get_zscore(series)
    return series[np.where(z_score > threshold)]


def get_outliers_using_modified_zscore(series, threshold=3.5):
    """
    Identify the outliers using modified Z-score method. 
    Overcome the limitations of Z-score method.
    """
    series = get_numpy_array(series)
    median = np.median(series)
    median_absolute_deviation = np.median([np.abs(val - median) for val in series])
    modified_z_scores = [0.6745 * (val - median) / median_absolute_deviation for val in series]
    return series[np.where(np.abs(modified_z_scores) > threshold)]


def get_iqr_range(series):
    """
    Get Interquartile range for given series
    """
    series = get_numpy_array(series)
    q1, q3 = np.percentile(series, [25, 75])
    iqr = q3 - q1
    lower_bound = q1 - (1.5 * iqr) 
    upper_bound = q3 + (1.5 * iqr)
    return lower_bound, upper_bound
    

def get_outliers_using_iqr(series):
    """
    Identify the outliers using interquartile range (IQR)
    """
    series = get_numpy_array(series)
    lbound, ubound = get_iqr_range(series)
    return [x for x in series if x < lbound or x > ubound]

# %%
def print_outliers(method, column):
    """
    Print outliers identified using given method and for given column of data.
    """
    if method == 'zscore':
        outliers = get_outliers_using_zscore(data[column])
    elif method == 'modified_zscore':
        outliers = get_outliers_using_modified_zscore(data[column])
    elif method == 'iqr':
        outliers = get_outliers_using_iqr(data[column])
    else:
        raise ValueError("Incorrect method value. Valid values: [zscore, modified_zscore, iqr]")
    
    print("\n{0} Outliers using '{1}' method: ".format(column, method), *outliers, sep="\n => ")

# %% [markdown]
# ### Outliers using Z-score

# %%
print_outliers(method='zscore', column='Signal')
print_outliers(method='zscore', column='ClosePrice')
# Out:
# Signal Outliers using 'zscore' method:
#  => 429.51456310679
#  => 432.96116504854
#
# ClosePrice Outliers using 'zscore' method:
#  => 618.95
#  => 619.33
#  => 710.31

# %% [markdown]
# ### Outliers usng Modified Z-score

# %%
print_outliers(method='modified_zscore', column='Signal')
print_outliers(method='modified_zscore', column='ClosePrice')
# Out:
# Signal Outliers using 'modified_zscore' method:
#  => -3.8026699029126
#  => 429.51456310679
#  => 432.96116504854
#  => 0.0045604368932038
#  => 0.45497572815533
#  => 0.45589805825242
#
# ClosePrice Outliers using 'modified_zscore' method:
#  => 618.95
#  => 619.33
#  => 710.31

# %% [markdown]
# ### Outliers using InterQuartile Range

# %%
print_outliers(method='iqr', column='Signal')
print_outliers(method='iqr', column='ClosePrice')
# Out:
# Signal Outliers using 'iqr' method:
#  => -3.8026699029126
#  => 429.51456310679
#  => 432.96116504854
#  => 0.0045604368932038
#  => 0.45497572815533
#  => 0.45589805825242
#
# ClosePrice Outliers using 'iqr' method:
#  => 618.95
#  => 619.33
#  => 710.31

# %% [markdown]
# > <font color='red'>**Comment:**
# > - As we can see from the above result, Modified Z-score and InterQuartile range methods works better in correctly identifying outliers compared to traditional Z-score method. This is evident from the additional outliers (very low values) detected in the `Signal` series by Modified Z-score and InterQuartile range, but not Z-score method.
# > - Let's proceed with InterQuartile range to identify these outliers (i.e. replace them with missing entries) and fix them by interpolating their values.

# %% [markdown]
# ## Fix the outliers using IQR method

# %%
# Make a copy of the data
clean_data = data.copy()

for col in clean_data.columns:
    # Get lower and upper bound for IQR and set outliers to NaN
    lbound, ubound = get_iqr_range(clean_data[col])
    clean_data[col] = np.where(np.logical_or(clean_data[col] < lbound, clean_data[col] > ubound), np.nan, clean_data[col])
    
    # Interpolate missing values
    clean_data[col] = clean_data[col].interpolate()

# %% [markdown]
# A good way to see if fixing the outliers solved the problem is to re-plot the original plots using cleaned data.

# %%
plots_for_outliers(clean_data)

# %% [markdown]
# > <font color='red'>**Comment:**
# > - Scatter plot clearly shows a linear relationship between `Signal` and `ClosePrice` after removing the outliers.
# > - Individual time-series plots also looks good.
# > - Box plot for both the series shows a clear interquartile range with min and max values highlighted.
# > - Our data is clean now and ready for analysis.

# %% [markdown]
# # Correlation between Signal and ClosePrice

# %%
# Pearson correlation metric using scipy stats function
r, p = stats.pearsonr(clean_data['Signal'], clean_data['ClosePrice'])
print(f"Pearson correlation: {r} and p-value: {p}" )
# Out:
# Pearson correlation: 0.9951522918139974 and p-value: 0.0

# %%
# Pearson correlation metric using pandas.corr() matrix
clean_data.corr(method='pearson')
# Out:
#               Signal  ClosePrice
# Signal      1.000000    0.995152
# ClosePrice  0.995152    1.000000

# %% [markdown]
# # Relationship between Signal and ClosePrice

# %% [markdown]
# From the scatter plot, we know there exists a linear relationship between `Signal` and `ClosePrice`. But we need to also check whether there exists any relationship between `Signal` and `ClosePrice` at different lags (if any for both the series).
#
# To achieve this, we calculate cross-correlation between the two time-series for different lags and plot it.

# %%
def plots_for_relationship(df):
    """
    Useful plots for checking relationship (via correlation) for two time-series
    """
    signal = df['Signal']
    close_price = df['ClosePrice']
    
    grid = gridspec.GridSpec(nrows=2, ncols=1)

    fig = plt.figure(figsize=(15, 7))
    fig.clf()

    # Add axes which can span multiple grid boxes
    ax1 = fig.add_subplot(grid[0, :])
    ax2 = fig.add_subplot(grid[1, :])
    
    # Cross correlation plot
    cross_correlation_plot(df, x='Signal', y='ClosePrice', ax=ax1)
    
    # Rolling correlation plots
    rolling_correlation_plot(df=df, ax=ax2)
    
    fig.tight_layout()
    plt.show()

# %%
plots_for_relationship(data)

# %% [markdown]
# > <font color='red'>**Comment:**
# > - With data including outliers, the highest correlation value of 0.36 between `Signal` and `ClosePrice` is obtained at Lag 37 of `Signal`

# %%
plots_for_relationship(clean_data)

# %% [markdown]
# > <font color='red'>**Comment:**
# > - With data that replaced outliers by interpolated values, the highest correlation value of 1.0 between `Signal` and `ClosePrice` is obtained at Lag 0 of `Signal`

# %% [markdown]
# # Modeling

# %% [markdown]
# Since there exists a linear relationship between `Signal` and `ClosePrice` after cleaning the data (i.e. from the earlier plots), let's apply simple linear regression to see if our independent variable `Signal` helps us to predict dependent variable `ClosePrice` of SPY.

# %%
def linear_regression(df, y_col, x_col=None, plot=False):
    """
    Perform linear regression and plot the regression line.
    """
    x_cols = []
    
    if x_col is None: 
        # If multiple regression, add all columns except y as X-variables
        x_cols = [col for col in df.columns if col != y_col]
    else:
        # Simple linear regression with just 1 independent variable
        x_cols = [x_col]

    # adding a intercept to X
    X = sm.add_constant(df[x_cols]) 
    Y = df[y_col]

    model = sm.OLS(Y, X).fit()
    print_model = model.summary()
    print(print_model)
    
    # Line of best fit
    if plot:
        fig, ax = plt.subplots(figsize=(15, 10))
        clean_data.plot(x=x_col, y=y_col, kind='scatter', ax=ax, label='Data Points')
        abline_plot(model_results=model, ax=ax, label='Fitted line')
        ax.set(title='Line of best-fit for Signal vs ClosePrice',
               xlabel=x_col, 
               ylabel=y_col)
        add_legend(ax)

        plt.show()

    return model

# %%
model = linear_regression(clean_data, x_col='Signal', y_col='ClosePrice', plot=True)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             ClosePrice   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 6.789e+04
# Date:                Thu, 06 Feb 2020   Prob (F-statistic):               0.00
# Time:                        23:06:25   Log-Likelihood:                -1439.1
# No. Observations:                 665   AIC:                             2882.
# Df Residuals:                     663   BIC:                             2891.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.6529      0.617      2.679      0.008       0.442       2.864
# ...

# %% [markdown]
# # Quality Check of Model

# %% [markdown]
# Quality check of our fitted model is very important to check if the fitted model does not violate the assumptions behind this simple linear model.
#
# These assumptions are:
#
# 1. Linear relationship between independent and dependent variable
#
# 2. Gauss-Markov Theorem: OLS estimator gives the best linear unbiased estimate (BLUE) of the coefficients, given:
#     - Mean or Expectation of error (residuals) is 0
#     - Errors are uncorrelated
#     - Errors are homoscedastic (i.e. they have equal variance)
#
# 3. Independent variables and residuals are uncorrelated
#
# 4. Normality of residuals
#
#
# Let's verify if these assumptions are not violated one-by-one.

# %% [markdown]
# ## Linear relationship

# %% [markdown]
# > <font color='red'>**Comment:**
# > - Linear relationship is clearly seen from the scatter plot of `Signal` against `ClosePrice`.

# %% [markdown]
# ## Mean of residuals should be 0

# %%
np.mean(model.resid)
# Out:
# -1.3676612056735762e-14

# %% [markdown]
# > <font color='red'>**Comment:**
# > - Mean of residual is very small (approximately equal to 0). So this assumption is not violated.

# %% [markdown]
# ## Residuals are homoscedastic

# %% [markdown]
# To check if residuals are homoscedastic, we can look at the plot of residuals vs predicted (fitted) values and perform Breusch-Pagan test.

# %% [markdown]
# ### Residual vs Fitted values plot

# %%
def homoscedastic_plot(model):
    """
    Plot for homoscedasticity check
    """
    fitted_values = model.predict()
    residuals = model.resid
    residuals_standardized = model.get_influence().resid_studentized_internal
    
    fig, ax = plt.subplots(1, 2, figsize=(15, 7))
    
    sns.regplot(x=fitted_values, y=residuals, lowess=True, ax=ax[0], line_kws={'color': 'red'})
    ax[0].set(title='Residuals vs Fitted', 
              xlabel='Fitted Values',
              ylabel='Residuals')
    
    sns.regplot(x=fitted_values, y=np.sqrt(np.abs(residuals_standardized)), lowess=True, ax=ax[1], line_kws={'color': 'red'})
    ax[1].set(title='Scale-Location', 
              xlabel='Fitted Values',
              ylabel='sqrt[abs(residuals)]')
    
    fig.tight_layout()
    plt.show()

# %%
homoscedastic_plot(model)

# %% [markdown]
# > <font color='red'>**Comment:**
# > - The points in the above plots should be random and no peculiar (increase or decrease) pattern in the values of residuals should be visible. Red line is relatively flat in our Residual vs Fitted plot. This indicates the errors are homoscedastic.

# %% [markdown]
# ### Breusch-Pagan Test

# %% [markdown]
# Breusch-Pagan test creates a statistic that is chi-squared distributed. p-value is the result of the chi-squared test and null hypothesis of homoscedasticity is rejected if p-value < 0.05

# %%
bp = pd.DataFrame(columns=['Values'], index=['Lagrange multiplier statistic', 'p-value', 'f-value', 'f p-value'])
bp['Values'] = sms.het_breuschpagan(model.resid, model.model.exog)
bp
# Out:
#                                   Values
# Lagrange multiplier statistic  14.422804
# p-value                         0.000146
# f-value                        14.698209
# f p-value                       0.000138

# %% [markdown]
# > <font color='red'>**Comment:**
# > - p-value in LM and F-test is lower than < 0.05, but not siginificantly low (close to 0). Thus, we have to reject the null hypothesis that errors (or residuals) are homoscedastic. Point to note that this test can give low p-value when the residuals are not heteroscedastic if the model is flawed (may be due to ommited variable bias).
# >
# > - Given the line in residual vs fitted value plot is quite flat, we can conclude that residuals are homoscedastic and Breusch-Pagan test is rejecting the null hypothesis due to some other flaws in the model.

# %% [markdown]
# ## Residuals are uncorrelated

# %% [markdown]
# Residuals should be uncorrelated. We can test it by plotting ACF (auto correlation function) plot and Durbin-Watson test.

# %% [markdown]
# ### Plotting Autocorrelation Function

# %%
def plot_acf(model):
    """
    Plot autocorrelation function
    """
    fig, ax = plt.subplots(figsize=(15, 7))    
    acf = smt.graphics.plot_acf(model.resid, lags=50, alpha=0.05, ax=ax)
    acf.show()

# %%
plot_acf(model)

# %% [markdown]
# > <font color='red'>**Comment:**
# > - ACF plot shows significant correlation at lags 1, 2 and 3. Thus it indicates the presence of positive serial autocorrelation.

# %% [markdown]
# ### Durbin-Watson Test
#
# This test statistic is used to detect the presence of autocorrelation at lag 1 in the residuals. Value of the test statistic is always between 0 and 4. If the value is 2, then there is no autocorrelation. If value < 2, then positive autocorrelation in residuals. If value > 2, negative autocorrelation in residuals exists.

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             ClosePrice   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 6.789e+04
# Date:                Thu, 06 Feb 2020   Prob (F-statistic):               0.00
# Time:                        23:17:50   Log-Likelihood:                -1439.1
# No. Observations:                 665   AIC:                             2882.
# Df Residuals:                     663   BIC:                             2891.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.6529      0.617      2.679      0.008       0.442       2.864
# ...

# %% [markdown]
# > <font color='red'>**Comment:**
# > - Durbin-Watson test value of 0.643 from the above summary shows that there is some positive autocorrelation (value < 2) in the residuals

# %% [markdown]
# ### Fix

# %% [markdown]
# Some of the ways to fix the serial autocorrelation problem of residuals are:
#
# > <font color='red'>**Comment:**
# > - Add more lagged terms in the independent variables
# > - Stationarize the time-series by differencing, taking logs etc.
# > - Use Generalized Least Squares

# %% [markdown]
# ## Independent variable and residuals are uncorrelated

# %%
correlation, p_value = stats.pearsonr(model.resid, model.model.endog)
print("Correlation between Signal column and residuals of model is {0:.4f} and corresponding p-value is {1:.3f}".format(correlation, p_value))
# Out:
# Correlation between Signal column and residuals of model is 0.0983 and corresponding p-value is 0.011

# %% [markdown]
# > <font color='red'>**Comment:**
# > - Correlation between `Signal` and residuals of the model is low and p-value is < 0.05. So we can reject the null hypothesis (lack of correlation).

# %% [markdown]
# ## Normality test of residuals

# %%
def qqplot(model):
    """
    QQ plot for residuals
    """
    fig, ax = plt.subplots(figsize=(10, 10))
    sm.ProbPlot(model.resid).qqplot(line='s', ax=ax)
    plt.show()

# %%
qqplot(model)

# %% [markdown]
# > <font color='red'>**Comment:**
# > - QQ-plot shows that residuals do not lie on the red-line and deviate from it at the ends. Thus the residuals do not follow Gaussian distribution.

# %% [markdown]
# ### Jarque-Barra test

# %%
jb = stats.jarque_bera(model.resid)
print("Jarque-Barra test for normality of residuals: ")
print("Statistics: {0} and p-value: {1}".format(jb[0], jb[1]))
# Out:
# Jarque-Barra test for normality of residuals:
# Statistics: 53.88044621856731 and p-value: 1.9952928198563313e-12

# %% [markdown]
# > <font color='red'>**Comment:**
# > - p-value is very low (<<< 0.05), thus we can reject the null hypothesis that residuals are normally distributed.

# %% [markdown]
# ### Fixes

# %% [markdown]
# Some of the ways to fix the normality of residuals problem:
#
# > <font color='red'>**Comment:**
# > - Current Model does not correctly/fully explain the data. We need to come up with a good enough model that can fully explain the data.

# %% [markdown]
# # Conclusion

# %% [markdown]
# > <font color='blue'>**To conclude:**
# >
# > - Despite `Signal` being a statistical significant predictor of `ClosePrice`, some of the assumptions of the linear model are violated and thus current model does not fully explain the data.
# >
# > - Newer model must overcome the shortcomings of our current model and ensure assumptions are satisfied (adding lagged variables, transforming the features, differencing of feature values, taking log, using Generalized Least Squares etc)

# %% [markdown]
# # Future Work:

# %% [markdown]
# ##  Feature Engineering

# %% [markdown]
# Feature engineering is a very important step in building a predictive machine learning model. Identifying the right set of features can help the model to perform better and higher accuracy.
#
# Features can be added to our data using following:
#
# - Add datetime based features
#
# - Add technical indicators as features of Signal value such as Relative Strength Index, Simple Moving Average, Exponential Moving Average etc.
#
# - Add lags/windowed values (mean, std etc.) of Signal value

# %% [markdown]
# ### DateTime-based features

# %%
def add_datetime_features(df):
    """
    Add features based on datetime index.
    """
    _df = df.copy()
    
    if not isinstance(_df.index, pd.DatetimeIndex):
        _df.index = pd.to_datetime(_df.index)
        
    # Add year, quarter, month, week, day
    _df['Year'] = _df.index.year
    _df['Quarter'] = _df.index.quarter
    _df['Month'] = _df.index.month
    _df['Week'] = _df.index.week
    _df['Day'] = _df.index.day
    
    # Add day of week
    _df['DayofWeek'] = _df.index.dayofweek

    return _df

# %%
clean_data_with_features = add_datetime_features(clean_data)
clean_data_with_features

# %% [markdown]
# ### Technical Indicators

# %% [markdown]
# More technical features can be added to build a predictive machine learning model
#
# - Simple Moving Average
# - Exponential Moving Average
# - Relative Strength Index
# - Moving Average Convergence Divergence (MACD) etc.

# %% [markdown]
# ### Lagged Features

# %% [markdown]
# Lagged features include
#
# - Adding lag terms for `Signal` at different lag levels etc.

# %% [markdown]
# ## Advanced Machine Learning Models

# %% [markdown]
# Once features are built, we can test various advanced machine learning models such as
#
# - Decision Trees & Random Forest
# - XGBoost (type of Gradient Boosting)
# - LightGBM (type of Gradient Boosting)
# - LSTM (Long Short-Term Memory - a type of recurrent neural network)
#
# to predict the SPY prices.
